# %%
import pandas as pd
import numpy as np
df=pd.read_csv('auto-mpg.csv')
print(df)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
print("DataFrame")
print(df)
print("Shape of df")
print(df.shape)
print("Size of df")
print(df.size)
print("Size of columns")
print(df.columns)
print("df.info")
print(df.info())
# Out:
# DataFrame
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
print("To get required data from from top of the data")
df.head(10)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
# 5  15.0          8         429.0        198    4341          10.0          70
# 6  14.0          8         454.0        220    4354           9.0          70
# 7  14.0          8         440.0        215    4312           8.5          70
# 8  14.0          8         455.0        225    4425          10.0          70
# 9  15.0          8         390.0        190    3850           8.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# ...

# %%
print("To get required data from from bottom of the data")
df.tail(10)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 388  26.0          4         156.0         92    2585          14.5
# 389  22.0          6         232.0        112    2835          14.7
# 390  32.0          4         144.0         96    2665          13.9
# 391  36.0          4         135.0         84    2370          13.0
# 392  27.0          4         151.0         90    2950          17.3
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                    car name
# 388          82       1  chrysler lebaron medallion
# 389          82       1              ford granada l
# 390          82       3            toyota celica gt
# ...

# %%
print("To print random 3 values")
df.sample(3)
# Out:
# To print random 3 values
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 51   30.0          4          79.0         70    2074          19.5
# 272  23.8          4         151.0         85    2855          17.6
# 311  32.1          4          98.0         70    2120          15.5
#
#      model year  origin                car name
# 51           71       2             peugeot 304
# 272          78       1  oldsmobile starfire sx
# 311          80       1      chevrolet chevette

# %%
df.values
# Out:
# array([[18.0, 8, 307.0, ..., 70, 1, 'chevrolet chevelle malibu'],
#        [15.0, 8, 350.0, ..., 70, 1, 'buick skylark 320'],
#        [18.0, 8, 318.0, ..., 70, 1, 'plymouth satellite'],
#        ...,
#        [32.0, 4, 135.0, ..., 82, 1, 'dodge rampage'],
#        [28.0, 4, 120.0, ..., 82, 1, 'ford ranger'],
#        [31.0, 4, 119.0, ..., 82, 1, 'chevy s-10']], dtype=object)

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
print("Describe method ")
print(df.describe())#gives float 
print("--------------------------------------------------------------")
print("Including Object in describe method")
print(df.describe(include='object'))
# Out:
# Describe method
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000
# ...

# %%
print("----------------------------------------------------------")
print("It will include all the object and numeric")
df.describe(include="all")
# Out:
# ----------------------------------------------------------
# It will include all the object and numeric
#                mpg   cylinders  displacement horsepower       weight  \
# count   398.000000  398.000000    398.000000        398   398.000000
# unique         NaN         NaN           NaN         94          NaN
# top            NaN         NaN           NaN        150          NaN
# freq           NaN         NaN           NaN         22          NaN
# mean     23.514573    5.454774    193.425879        NaN  2970.424623
# std       7.815984    1.701004    104.269838        NaN   846.841774
# min       9.000000    3.000000     68.000000        NaN  1613.000000
# 25%      17.500000    4.000000    104.250000        NaN  2223.750000
# 50%      23.000000    4.000000    148.500000        NaN  2803.500000
# 75%      29.000000    8.000000    262.000000        NaN  3608.000000
# max      46.600000    8.000000    455.000000        NaN  5140.000000
#
# ...

# %%
df.describe(include=['int64','float'])
df.describe(exclude='int64')
# Out:
#                mpg  displacement horsepower  acceleration    car name
# count   398.000000    398.000000        398    398.000000         398
# unique         NaN           NaN         94           NaN         305
# top            NaN           NaN        150           NaN  ford pinto
# freq           NaN           NaN         22           NaN           6
# mean     23.514573    193.425879        NaN     15.568090         NaN
# std       7.815984    104.269838        NaN      2.757689         NaN
# min       9.000000     68.000000        NaN      8.000000         NaN
# 25%      17.500000    104.250000        NaN     13.825000         NaN
# 50%      23.000000    148.500000        NaN     15.500000         NaN
# 75%      29.000000    262.000000        NaN     17.175000         NaN
# max      46.600000    455.000000        NaN     24.800000         NaN

# %%
df.nunique()#gives count of column
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       94
# weight          351
# acceleration     95
# model year       13
# origin            3
# car name        305
# dtype: int64

# %%
print("to print unique car names")
df['car name'].unique()
# Out:
# array(['chevrolet chevelle malibu', 'buick skylark 320',
#        'plymouth satellite', 'amc rebel sst', 'ford torino',
#        'ford galaxie 500', 'chevrolet impala', 'plymouth fury iii',
#        'pontiac catalina', 'amc ambassador dpl', 'dodge challenger se',
#        "plymouth 'cuda 340", 'chevrolet monte carlo',
#        'buick estate wagon (sw)', 'toyota corona mark ii',
#        'plymouth duster', 'amc hornet', 'ford maverick', 'datsun pl510',
#        'volkswagen 1131 deluxe sedan', 'peugeot 504', 'audi 100 ls',
#        'saab 99e', 'bmw 2002', 'amc gremlin', 'ford f250', 'chevy c20',
#        'dodge d200', 'hi 1200d', 'chevrolet vega 2300', 'toyota corona',
#        'ford pinto', 'plymouth satellite custom', 'ford torino 500',
#        'amc matador', 'pontiac catalina brougham', 'dodge monaco (sw)',
#        'ford country squire (sw)', 'pontiac safari (sw)',
#        'amc hornet sportabout (sw)', 'chevrolet vega (sw)',
# ...

# %%
df['car name'].value_counts()
# Out:
# ford pinto          6
# ford maverick       5
# amc matador         5
# toyota corolla      5
# amc gremlin         4
#                    ..
# vw rabbit custom    1
# volvo 245           1
# toyota carina       1
# amc pacer d/l       1
# ford fairmont       1
# Name: car name, Length: 305, dtype: int64

# %%
df['car name'].value_counts(ascending=True)
# Out:
# ford fairmont       1
# amc pacer d/l       1
# toyota carina       1
# volvo 245           1
# vw rabbit custom    1
#                    ..
# amc gremlin         4
# toyota corolla      5
# amc matador         5
# ford maverick       5
# ford pinto          6
# Name: car name, Length: 305, dtype: int64

# %%
df['car name'].value_counts(ascending=False)
# Out:
# ford pinto          6
# ford maverick       5
# amc matador         5
# toyota corolla      5
# amc gremlin         4
#                    ..
# vw rabbit custom    1
# volvo 245           1
# toyota carina       1
# amc pacer d/l       1
# ford fairmont       1
# Name: car name, Length: 305, dtype: int64
